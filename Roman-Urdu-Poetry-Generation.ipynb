# %%
import pandas as pd

# Load the CSV file
df = pd.read_csv('Roman-Urdu-Poetry.csv')

# Check the first few rows of the data
print(df.head())
# Out:
#    ID         Poet                                             Poetry
# 0   1  ahmad-faraz  aañkh se duur na ho dil se utar jā.egā \nvaqt ...
# 1   2  ahmad-faraz  āshiqī meñ 'mīr' jaise ḳhvāb mat dekhā karo \n...
# 2   3  ahmad-faraz  ab aur kyā kisī se marāsim baḌhā.eñ ham \nye b...
# 3   4  ahmad-faraz  ab ke ham bichhḌe to shāyad kabhī ḳhvāboñ meñ ...
# 4   5  ahmad-faraz  ab ke tajdīd-e-vafā kā nahīñ imkāñ jānāñ \nyaa...

# %%
# Check the columns
print(df.columns)
# Out:
# Index(['ID', 'Poet', 'Poetry'], dtype='object')

# %%
# Check the first few entries in the 'Poetry' column
print(df['Poetry'].head())
# Out:
# 0    aañkh se duur na ho dil se utar jā.egā \nvaqt ...
# 1    āshiqī meñ 'mīr' jaise ḳhvāb mat dekhā karo \n...
# 2    ab aur kyā kisī se marāsim baḌhā.eñ ham \nye b...
# 3    ab ke ham bichhḌe to shāyad kabhī ḳhvāboñ meñ ...
# 4    ab ke tajdīd-e-vafā kā nahīñ imkāñ jānāñ \nyaa...
# Name: Poetry, dtype: object

# %%
# Check for missing values in the Poetry column
print(df['Poetry'].isnull().sum())
# Out:
# 0

# %%
# Check for duplicate poems
print(df['Poetry'].duplicated().sum())
# Out:
# 0

# %%
import re  # Add this to import the 're' module

# Revised text cleaning approach
def clean_text(text):
    text = text.lower()  # Convert to lowercase
    text = re.sub(r"[^a-zA-Zñḳḍāī\s]", "", text)  # Keep letters, diacritics, apostrophes
    text = re.sub(r'(\n)(\S)', r'\1 \2', text)
    return text

# Apply revised cleaning function to the poetry column
df['Poetry'] = df['Poetry'].apply(clean_text)

# Inspect the cleaned data again
print(df['Poetry'].head())
# Out:
# 0    aañkh se duur na ho dil se utar jāegā \n vaqt ...
# 1    āshiqī meñ mīr jaise ḳhvāb mat dekhā karo \n b...
# 2    ab aur kyā kisī se marāsim baḍhāeñ ham \n ye b...
# 3    ab ke ham bichhḍe to shāyad kabhī ḳhvāboñ meñ ...
# 4    ab ke tajdīdevafā kā nahīñ imkāñ jānāñ \n yaad...
# Name: Poetry, dtype: object

# %%
from tensorflow.keras.preprocessing.text import Tokenizer

tokenizer = Tokenizer(num_words=5000, filters='')
tokenizer.fit_on_texts(df['Poetry'])

# Convert text to sequences of tokens (integers)
sequences = tokenizer.texts_to_sequences(df['Poetry'])

# %%
sample_text = "This is a poem.\nHello world."
cleaned_text = clean_text(sample_text)
tokens = tokenizer.texts_to_sequences([cleaned_text])
print(tokenizer.word_index)
# Out:
# {'\n': 1, 'hai': 2, 'se': 3, 'meñ': 4, 'ke': 5, 'kī': 6, 'ko': 7, 'na': 8, 'haiñ': 9, 'bhī': 10, 'to': 11, 'kā': 12, 'nahīñ': 13, 'ham': 14, 'ki': 15, 'kyā': 16, 'ho': 17, 'vo': 18, 'ye': 19, 'jo': 20, 'dil': 21, 'ne': 22, 'thā': 23, 'us': 24, 'maiñ': 25, 'kar': 26, 'koī': 27, 'hī': 28, 'huuñ': 29, 'aur': 30, 'kuchh': 31, 'par': 32, 'ab': 33, 'pe': 34, 'gayā': 35, 'ik': 36, 'har': 37, 'huā': 38, 'ai': 39, 'mujhe': 40, 'phir': 41, 'is': 42, 't': 43, 'mujh': 44, 'o': 45, 'kis': 46, 'rahā': 47, 'jab': 48, 'thī': 49, 'ek': 50, 'tum': 51, 'jis': 52, 'kabhī': 53, 'kyuuñ': 54, 'the': 55, 'mire': 56, 'kisī': 57, 'gaī': 58, 'aa': 59, 'kahāñ': 60, 'tak': 61, 'bahut': 62, 'apne': 63, 'aaj': 64, 'magar': 65, 'ishq': 66, 'kiyā': 67, 'rahe': 68, 'baat': 69, 'tire': 70, 'tirī': 71, 'un': 72, 'gae': 73, 'sab': 74, 'tujh': 75, 'dekh': 76, 'nazar': 77, 'apnī': 78, 'hue': 79, 'jaae': 80, 'hotā': 81, 'mirī': 82, 'de': 83, 'huī': 84, 'diyā': 85, 'liye': 86, 'yaad': 87, 'agar': 88, 'mere': 89, 'ghar': 90, 'merī': 91, 'aap': 92, 'tarah': 93, 'din': 94, 'aayā': 95, 'kahīñ': 96, 'apnā': 97, 'aae': 98, 'zindagī': 99, 'terī': 100, 'yuuñ': 101, 'jaane': 102, 'vahī': 103, 'raat': 104, 'saath': 105, 'jā': 106, 'abhī': 107, 'duniyā': 108, 'yā': 109, 'kare': 110, 'merā': 111, 'ḳhudā': 112, 'kaun': 113, 'tere': 114, 'haath': 115, 'mirā': 116, 'kab': 117, 'jahāñ': 118, 'gar': 119, 'le': 120, 'ḳhud': 121, 'lekin': 122, 'use': 123, 'rahī': 124, 'rah': 125, 'dekhā': 126, 'karte': 127, 'tirā': 128, 'hameñ': 129, 'sar': 130, 'hogā': 131, 'sī': 132, 'log': 133, 'jaatā': 134, 'terā': 135, 'kahte': 136, 'sā': 137, 'āñkhoñ': 138, 'jaate': 139, 'jaan': 140, 'kaam': 141, 'tujhe': 142, 'jaanā': 143, 'aatā': 144, 'bhar': 145, 'chale': 146, 'dard': 147, 'do': 148, 'naam': 149, 'shahr': 150, 'rañg': 151, 'aate': 152, 'yaañ': 153, 'aaī': 154, 'liyā': 155, 'taraf': 156, 'aañkh': 157, 'vaqt': 158, 'duur': 159, 'mohabbat': 160, 'yahī': 161, 'dekhte': 162, 'kam': 163, 'chāhiye': 164, 'baar': 165, 'hālib': 166, 'dar': 167, 'havā': 168, 'ḳhaak': 169, 'yahāñ': 170, 'chhoḍ': 171, 'aise': 172, 'pahle': 173, 'bas': 174, 'hotī': 175, 'āḳhir': 176, 'ḳhabar': 177, 'kah': 178, 'hote': 179, 'sahī': 180, 'jaise': 181, 'husn': 182, 'niklā': 183, 'shāyad': 184, 'jī': 185, 'zarā': 186, 'kaise': 187, 'chāñd': 188, 'jaatī': 189, 'umr': 190, 'āñkheñ': 191, 'mar': 192, 'aisā': 193, 'jise': 194, 'pchh': 195, 'so': 196, 'miltā': 197, 'suuñ': 198, 'jaaeñ': 199, 'vaale': 200, 'lagā': 201, 'ḳhvāb': 202, 'kahā': 203, 'baad': 204, 'dam': 205, 'kiye': 206, 'kal': 207, 'jin': 208, 'lagtā': 209, 'ban': 210, 'haal': 211, 'dī': 212, 'karo': 213, 'zamāne': 214, 'aatī': 215, 'muñh': 216, 'asad': 217, 'kuuñ': 218, 'shaam': 219, 'phuul': 220, 'mile': 221, 'raah': 222, 'nikle': 223, 'shab': 224, 'baithe': 225, 'aisī': 226, 'usī': 227, 'milā': 228, 'jāegā': 229, 'kareñ': 230, 'dost': 231, 'baaqī': 232, 'jigar': 233, 'guzar': 234, 'hamāre': 235, 'dariyā': 236, 'hair': 237, 'pyaar': 238, 'mat': 239, 'lage': 240, 'aalam': 241, 'qayāmat': 242, 'aage': 243, 'uthā': 244, 'aadmī': 245, 'itnā': 246, 'ḳhayāl': 247, 'srat': 248, 'tumheñ': 249, 'kahñ': 250, 'varna': 251, 'chal': 252, 'lab': 253, 'achchhā': 254, 'nigāh': 255, 'in': 256, 'banā': 257, 'qadam': 258, 'saaqī': 259, 'qadar': 260, 'subh': 261, 'sadā': 262, 'saktā': 263, 'lah': 264, 'gul': 265, 'bhuul': 266, 'rakh': 267, 'sunā': 268, 'aah': 269, 'bāteñ': 270, 'hamārī': 271, 'sivā': 272, 'ajab': 273, 'kahiye': 274, 'adā': 275, 'isī': 276, 'gaiiñ': 277, 'tamām': 278, 'zabāñ': 279, 'hijr': 280, 'kartā': 281, 'zamīñ': 282, 'maalm': 283, 'firāq': 284, 'tanhā': 285, 'hoñ': 286, 'aane': 287, 'zamāna': 288, 'mil': 289, 'shaḳhs': 290, 'aag': 291, 'ḳhush': 292, 'zaḳhm': 293, 'haae': 294, 'paas': 295, 'kaho': 296, 'dekhnā': 297, 'yaar': 298, 'vafā': 299, 'roz': 300, 'paañv': 301, 'chaman': 302, 'vaalā': 303, 'jaañ': 304, 'aave': 305, 'lete': 306, 'safar': 307, 'āsmāñ': 308, 'samajh': 309, 'judā': 310, 'sun': 311, 'kartī': 312, 'maut': 313, 'kyñkar': 314, 'paayā': 315, 'dekho': 31 ...

# %%
from tensorflow.keras.preprocessing.sequence import pad_sequences

# Pad sequences to the same length
max_sequence_len = max([len(seq) for seq in sequences])  # Find the maximum sequence length
max_sequence_len = min(max_sequence_len, 225)  # Limit sequence length to 100 (or smaller)
padded_sequences = pad_sequences(sequences, maxlen=max_sequence_len, padding='pre')

# Check the shape of padded sequences
print(padded_sequences.shape)
print(max_sequence_len)
# Out:
# (1314, 225)
# 225

# %%
from tensorflow.keras import backend as K
K.clear_session()
# Out:
# WARNING:tensorflow:From C:\Users\abdul\anaconda3\Lib\site-packages\keras\src\backend\common\global_state.py:82: The name tf.reset_default_graph is deprecated. Please use tf.compat.v1.reset_default_graph instead.

# %%
import numpy as np

# Define input and output sequences
input_sequences = []
output_words = []

for seq in padded_sequences:
    for i in range(1, len(seq)):
        input_sequences.append(seq[:i])
        output_words.append(seq[i])

input_sequences = pad_sequences(input_sequences, maxlen=max_sequence_len, padding='pre')
output_words = np.array(output_words)

# %%
from tensorflow.keras.utils import to_categorical

# Number of unique words (size of the vocabulary)
total_words = len(tokenizer.word_index) + 1

# One-hot encode the output words
#output_words = to_categorical(output_words, num_classes=total_words)

# %%
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Embedding, LSTM, Dense

# Create a MirroredStrategy
strategy = tf.distribute.MirroredStrategy()

# Define the model within the strategy scope
with strategy.scope():
    model = Sequential()
    model.add(Embedding(input_dim=total_words, output_dim=300, input_shape=(max_sequence_len-1,)))
    model.add(LSTM(250))
    model.add(Dense(total_words, activation='softmax'))

    model.compile(loss='sparse_categorical_crossentropy', optimizer='adam', metrics=['accuracy'])

model.summary()
# Out:
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/core/embedding.py:93: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ embedding (Embedding)                │ (None, 224, 300)            │       5,151,000 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ lstm (LSTM)                          │ (None, 250)                 │         551,000 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense (Dense)                        │ (None, 17170)               │       4,309,670 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 10,011,670 (38.19 MB)
#  Trainable params: 10,011,670 (38.19 MB)
#  Non-trainable params: 0 (0.00 B)

# %%
from tensorflow.keras.models import load_model

model = load_model('final_poetry_model_with_endline.h5')
# Out:
# WARNING:absl:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.

# %%
history = model.fit(input_sequences, output_words, epochs=50, batch_size=64)
# Out:
# Epoch 1/50
# 4599/4599 ━━━━━━━━━━━━━━━━━━━━ 150s 32ms/step - accuracy: 0.5437 - loss: 3.3249
# Epoch 2/50
# 4599/4599 ━━━━━━━━━━━━━━━━━━━━ 201s 32ms/step - accuracy: 0.5684 - loss: 2.8270
# Epoch 3/50
# 4599/4599 ━━━━━━━━━━━━━━━━━━━━ 202s 32ms/step - accuracy: 0.5833 - loss: 2.6380
# Epoch 4/50
# 4599/4599 ━━━━━━━━━━━━━━━━━━━━ 202s 32ms/step - accuracy: 0.5951 - loss: 2.4467
# Epoch 5/50
# 4599/4599 ━━━━━━━━━━━━━━━━━━━━ 202s 32ms/step - accuracy: 0.6083 - loss: 2.2578
# Epoch 6/50
# 4599/4599 ━━━━━━━━━━━━━━━━━━━━ 202s 32ms/step - accuracy: 0.6246 - loss: 2.0669
# Epoch 7/50
# 4599/4599 ━━━━━━━━━━━━━━━━━━━━ 202s 32ms/step - accuracy: 0.6457 - loss: 1.8776
# Epoch 8/50
# 4599/4599 ━━━━━━━━━━━━━━━━━━━━ 202s 32ms/step - accuracy: 0.6685 - loss: 1.7089
# Epoch 9/50
# 4599/4599 ━━━━━━━━━━━━━━━━━━━━ 202s 32ms/step - accuracy: 0.6954 - loss: 1.5416
# Epoch 10/50
# 4599/4599 ━━━━━━━━━━━━━━━━━━━━ 202s 32ms/step - accuracy: 0.7202 - loss: 1.4023
# Epoch 11/50
# 4599/4599 ━━━━━━━━━━━━━━━━━━━━ 147s 32ms/step - accuracy: 0.7419 - loss: 1.2807
# Epoch 12/50
# 4599/4599 ━━━━━━━━━━━━━━━━━━━━ 202s 32ms/step - accuracy: 0.7644 - loss: 1.1681
# Epoch 13/50
# 4599/4599 ━━━━━━━━━━━━━━━━━━━━ 202s 32ms/step - accuracy: 0.7831 - loss: 1.0638
# Epoch 14/50
# 4599/4599 ━━━━━━━━━━━━━━━━━━━━ 202s 32ms/step - accuracy: 0.8011 - loss: 0.9728
# Epoch 15/50
# 4599/4599 ━━━━━━━━━━━━━━━━━━━━ 202s 32ms/step - accuracy: 0.8169 - loss: 0.8934
# Epoch 16/50
# 4599/4599 ━━━━━━━━━━━━━━━━━━━━ 202s 32ms/step - accuracy: 0.8305 - loss: 0.8210
# Epoch 17/50
# 4599/4599 ━━━━━━━━━━━━━━━━━━━━ 202s 32ms/step - accuracy: 0.8432 - loss: 0.7603
# Epoch 18/50
# 4599/4599 ━━━━━━━━━━━━━━━━━━━━ 202s 32ms/step - accuracy: 0.8527 - loss: 0.7113
# Epoch 19/50
# 4599/4599 ━━━━━━━━━━━━━━━━━━━━ 202s 32ms/step - accuracy: 0.8633 - loss: 0.6601
# Epoch 20/50
# 4599/4599 ━━━━━━━━━━━━━━━━━━━━ 202s 32ms/step - accuracy: 0.8718 - loss: 0.6172
# Epoch 21/50
# 4599/4599 ━━━━━━━━━━━━━━━━━━━━ 147s 32ms/step - accuracy: 0.8792 - loss: 0.5788
# Epoch 22/50
# 4599/4599 ━━━━━━━━━━━━━━━━━━━━ 202s 32ms/step - accuracy: 0.8865 - loss: 0.5450
# Epoch 23/50
# 4599/4599 ━━━━━━━━━━━━━━━━━━━━ 202s 32ms/step - accuracy: 0.8921 - loss: 0.5131
# Epoch 24/50
# 4599/4599 ━━━━━━━━━━━━━━━━━━━━ 202s 32ms/step - accuracy: 0.8968 - loss: 0.4908
# Epoch 25/50
# 4599/4599 ━━━━━━━━━━━━━━━━━━━━ 202s 32ms/step - accuracy: 0.9028 - loss: 0.4635
# Epoch 26/50
# 4599/4599 ━━━━━━━━━━━━━━━━━━━━ 147s 32ms/step - accuracy: 0.9052 - loss: 0.4464
# Epoch 27/50
# 4599/4599 ━━━━━━━━━━━━━━━━━━━━ 202s 32ms/step - accuracy: 0.9090 - loss: 0.4288
# Epoch 28/50
# 4599/4599 ━━━━━━━━━━━━━━━━━━━━ 202s 32ms/step - accuracy: 0.9123 - loss: 0.4084
# Epoch 29/50
# 4599/4599 ━━━━━━━━━━━━━━━━━━━━ 202s 32ms/step - accuracy: 0.9149 - loss: 0.3960
# Epoch 30/50
# 4599/4599 ━━━━━━━━━━━━━━━━━━━━ 202s 32ms/step - accuracy: 0.9174 - loss: 0.3820
# Epoch 31/50
# 4599/4599 ━━━━━━━━━━━━━━━━━━━━ 147s 32ms/step - accuracy: 0.9198 - loss: 0.3712
# Epoch 32/50
# 4599/4599 ━━━━━━━━━━━━━━━━━━━━ 147s 32ms/step - accuracy: 0.9193 - loss: 0.3679
# Epoch 33/50
# 4599/4599 ━━━━━━━━━━━━━━━━━━━━ 203s 32ms/step - accuracy: 0.9216 - loss: 0.3591
# Epoch 34/50
# 4599/4599 ━━━━━━━━━━━━━━━━━━━━ 202s 32ms/step - accuracy: 0.9238 - loss: 0.3457
# Epoch 35/50
# 4599/4599 ━━━━━━━━━━━━━━━━━━━━ 202s 32ms/step - accuracy: 0.9244 - loss: 0.3428
# Epoch 36/50
# 4599/4599 ━━━━━━━━━━━━━━━━━━━━ 202s 32ms/step - accuracy: 0.9242 - loss: 0.3410
# Epoch 37/50
# 4599/4599 ━━━━━━━━━━━━━━━━━━━━ 202s 32ms/step - accuracy: 0.9262 - loss: 0.3315
# Epoch 38/50
# 4599/4599 ━━━━━━━━━━━━━━━━━━━━ 201s 32ms/step - accuracy: 0.9255 - loss: 0.3292
# Epoch 39/50
# 4599/4599 ━━━━━━━━━━━━━━━━━━━━ 202s 32ms/step - accuracy: 0.9276 - loss: 0.3235
# Epoch 40/50
# 4599/4599 ━━━━━━━━━━━━━━━━━━━━ 203s 32ms/step - accuracy: 0.9255 - loss: 0.3290
# Epoch 41/50
# 4599/4599 ━━━━━━━━━━━━━━━━━━━━ 201s 32ms/step - accuracy: 0.9277 - loss: 0.3191
# Epoch 42/50
# 4599/4599 ━━━━━━━━━━━━━━━━━━━━ 147s 32ms/step - accuracy: 0.9265 - loss: 0.3209
# Epoch 43/50
# 4599/4599 ━━━━━━━━━━━━━━━━━━━━ 202s 32ms/step - accuracy: 0.9278 - loss: 0.3147
# Epoch 44/50
# 4599/4599 ━━━━━━━━━━━━━━━━━━━━ 203s 32ms/step - accuracy: 0.9276 - loss: 0.3128
# Epoch 45/50
# 4599/4599 ━━━━━━━━━━━━━━━━━━━━ 148s 32ms/step - accuracy: 0.9288 - loss: 0.3092
# Epoch 46/50
# 4599/4599 ━━━━━━━━━━━━━━━━━━━━ 147s 32ms/step - accuracy: 0.9254 - loss: 0.3182
# Epoch 47/50
# 4599/4599 ━━━━━━━━━━━━━━━━━━━━ 202s 32ms/step - accuracy: 0.9267 - loss: 0.3131
# Epoch 48/50
# 4599/4599 ━━━━━━━━━━━━━━━━━━━━ 202s 32ms/step - accuracy: 0.9255 - loss: 0.3142
# Epoch 49/50
# 4599/4599 ━━━━━━━━━━━━━━━━━━━━ 201s 32ms/step - accuracy: 0.9251 - loss: 0.3161
# Epoch 50/50
# 4599/4599 ━━━━━━━━━━━━━━━━━━━━ 203s 32ms/step - accuracy: 0.9246 - loss: 0.3142

# %%
def generate_poem(seed_text, next_words, max_sequence_len):
    for _ in range(next_words):
        token_list = tokenizer.texts_to_sequences([seed_text])[0]
        token_list = pad_sequences([token_list], maxlen=max_sequence_len-1, padding='pre')
        predicted = model.predict(token_list, verbose=0)
        predicted_word_index = np.argmax(predicted, axis=1)[0]
        predicted_word = tokenizer.index_word.get(predicted_word_index, '')
        seed_text += " " + predicted_word
    return seed_text

# Example usage
seed_text = "dhuup"
generated_poem = generate_poem(seed_text, next_words=80, max_sequence_len=max_sequence_len)
print(generated_poem)
# Out:
# dhuup meñ niklo ghatāoñ meñ nahā kar dekho
#  zindagī kyā hai kitāboñ ko hatā kar dekho
#  sirf āñkhoñ se hī ḳhudkushī kā jaane de
#  us ko dekh kar vo kyā hogā
#  itnā māns na ho ai vaada
#  hai takrār na taalluq se nigāheñ
#  kyā jāniye in se mohabbat kabhī bazmedushman meñ
#  aa ki hī tanhā thā kahīñ
#  aur yahāñ koī naam merā ghar jaanā bhī ho
#  ḳhudā kī hī nahīñ hotī to
